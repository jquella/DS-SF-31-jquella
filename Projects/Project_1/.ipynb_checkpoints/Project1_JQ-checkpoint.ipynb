# %%
import numpy as np
import pandas as pd
import os
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib as mpl

mpl.rcParams['figure.figsize'] = (15, 6)
pd.set_option('display.width', 4000)
pd.set_option('display.max_columns', 100)

try:
    data = pd.read_csv(r'C:\Users\jquella\GA-DataScience\Projects\Project_1\admissions.csv')
    print "Admissions data set has {} samples with {} features each.".format(*data.shape)
except:
    print "Dataset not loaded - did you do it right?"
# Out:
# Admissions data set has 400 samples with 4 features each.

# %%
data.head()
# Out:
#    admit    gre   gpa  prestige
# 0      0  380.0  3.61       3.0
# 1      1  660.0  3.67       3.0
# 2      1  800.0  4.00       1.0
# 3      1  640.0  3.19       4.0
# 4      0  520.0  2.93       4.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 4 columns):
# admit       400 non-null int64
# gre         398 non-null float64
# gpa         398 non-null float64
# prestige    399 non-null float64
# dtypes: float64(3), int64(1)
# memory usage: 12.6 KB

# %%
data.describe()
# Out:
#             admit         gre        gpa    prestige
# count  400.000000  398.000000  398.00000  399.000000
# mean     0.317500  588.040201    3.39093    2.486216
# std      0.466087  115.628513    0.38063    0.945333
# min      0.000000  220.000000    2.26000    1.000000
# 25%      0.000000         NaN        NaN         NaN
# 50%      0.000000         NaN        NaN         NaN
# 75%      1.000000         NaN        NaN         NaN
# max      1.000000  800.000000    4.00000    4.000000

# %%
data_drop = data.copy().dropna()

# %%
data_drop.describe()
# Out:
#             admit         gre         gpa    prestige
# count  397.000000  397.000000  397.000000  397.000000
# mean     0.317380  587.858942    3.392242    2.488665
# std      0.466044  115.717787    0.380208    0.947083
# min      0.000000  220.000000    2.260000    1.000000
# 25%      0.000000  520.000000    3.130000    2.000000
# 50%      0.000000  580.000000    3.400000    2.000000
# 75%      1.000000  660.000000    3.670000    3.000000
# max      1.000000  800.000000    4.000000    4.000000

# %%
plt.scatter(data['gpa'], data['gre'], marker='.', color="blue")

# %%
pd.scatter_matrix(data, alpha = 0.3, figsize = (8,4), diagonal = 'kde');

# %%
#gre
data['gre'].plot(kind='box')

# %%
#gpa
data['gpa'].plot(kind='box')

# %%
data['gre'].plot(kind='hist')

# %%
data['gpa'].plot(kind='hist')

# %%
data['prestige'].plot(kind='hist')
